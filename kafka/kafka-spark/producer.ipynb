# %%
import pandas as pd
from kafka import KafkaProducer
from datetime import datetime
import time
import random
import numpy as np

# %%
KAFKA_TOPIC_NAME_CONS = "topic1"
KAFKA_BOOTSTRAP_SERVERS_CONS = 'localhost:9092'

# %%
kafka_producer_obj = KafkaProducer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS_CONS,
                                    api_version=(0,11,5),
                                    value_serializer=lambda x: x.encode('utf-8'))

filepath = "iris.csv"

flower_df = pd.read_csv(filepath)

flower_df['order_id'] = np.arange(len(flower_df))


flower_list = flower_df.to_dict(orient="records")

# %%
print("Kafka Producer Application Started ... ")
message_list = []
message = None
for message in flower_list:

    message_fields_value_list = []

    message_fields_value_list.append(message["sepal_length"])
    message_fields_value_list.append(message["sepal_width"])
    message_fields_value_list.append(message["petal_length"])
    message_fields_value_list.append(message["petal_width"])
    message_fields_value_list.append(message["species"])

    message = ','.join(str(v) for v in message_fields_value_list)
    print("Message Type: ", type(message))
    print("Message: ", message)
    kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
    print("Wait")
    time.sleep(1)


print("Kafka Producer Application Completed. ")
# Out:
# Kafka Producer Application Started ...
# Message Type:  <class 'str'>
# Message:  5.1,3.5,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.9,3.0,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.7,3.2,1.3,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.6,3.1,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.6,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.4,3.9,1.7,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.6,3.4,1.4,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.4,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.4,2.9,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.9,3.1,1.5,0.1,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.4,3.7,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.8,3.4,1.6,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.8,3.0,1.4,0.1,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.3,3.0,1.1,0.1,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.8,4.0,1.2,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,4.4,1.5,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.4,3.9,1.3,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.5,1.4,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,3.8,1.7,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.8,1.5,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.4,3.4,1.7,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.7,1.5,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.6,3.6,1.0,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.3,1.7,0.5,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.8,3.4,1.9,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.0,1.6,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.4,1.6,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.2,3.5,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.2,3.4,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.7,3.2,1.6,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.8,3.1,1.6,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.4,3.4,1.5,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.2,4.1,1.5,0.1,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,4.2,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.9,3.1,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.2,1.2,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,3.5,1.3,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.9,3.6,1.4,0.1,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.4,3.0,1.3,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.4,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.5,1.3,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.5,2.3,1.3,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.4,3.2,1.3,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.5,1.6,0.6,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.8,1.9,0.4,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.8,3.0,1.4,0.3,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,3.8,1.6,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  4.6,3.2,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.3,3.7,1.5,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,3.3,1.4,0.2,Setosa
# Wait
# Message Type:  <class 'str'>
# Message:  7.0,3.2,4.7,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.4,3.2,4.5,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.9,3.1,4.9,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,2.3,4.0,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.5,2.8,4.6,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,2.8,4.5,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.3,3.3,4.7,1.6,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  4.9,2.4,3.3,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.6,2.9,4.6,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.2,2.7,3.9,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,2.0,3.5,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.9,3.0,4.2,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.0,2.2,4.0,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.1,2.9,4.7,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.6,2.9,3.6,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.7,3.1,4.4,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.6,3.0,4.5,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.8,2.7,4.1,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.2,2.2,4.5,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.6,2.5,3.9,1.1,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.9,3.2,4.8,1.8,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.1,2.8,4.0,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.3,2.5,4.9,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.1,2.8,4.7,1.2,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.4,2.9,4.3,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.6,3.0,4.4,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.8,2.8,4.8,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.7,3.0,5.0,1.7,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.0,2.9,4.5,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,2.6,3.5,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,2.4,3.8,1.1,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,2.4,3.7,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.8,2.7,3.9,1.2,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.0,2.7,5.1,1.6,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.4,3.0,4.5,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.0,3.4,4.5,1.6,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.7,3.1,4.7,1.5,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.3,2.3,4.4,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.6,3.0,4.1,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,2.5,4.0,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.5,2.6,4.4,1.2,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.1,3.0,4.6,1.4,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.8,2.6,4.0,1.2,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.0,2.3,3.3,1.0,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.6,2.7,4.2,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,3.0,4.2,1.2,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,2.9,4.2,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.2,2.9,4.3,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.1,2.5,3.0,1.1,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  5.7,2.8,4.1,1.3,Versicolor
# Wait
# Message Type:  <class 'str'>
# Message:  6.3,3.3,6.0,2.5,Virginica
# Wait
# Message Type:  <class 'str'>
# Message:  5.8,2.7,5.1,1.9,Virginica
# Wait
# Message Type:  <class 'str'>
# Message:  7.1,3.0,5.9,2.1,Virginica
# Wait
# Message Type:  <class 'str'>
# Message:  6.3,2.9,5.6,1.8,Virginica
# Wait
# Message Type:  <class 'str'>
# Message:  6.5,3.0,5.8,2.2,Virginica
# Wait
# Message Type:  <class 'str'>
# Message:  7.6,3.0,6.6,2.1,Virginica
# Wait
# Message Type:  <class 'str'>
# Message:  4.9,2.5,4.5,1.7,Virginica
# Wait

# %%
kafka_producer_obj = KafkaProducer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS_CONS,
                                    api_version=(0,11,5),
                                    value_serializer=lambda x: x.dumps(x).encode('utf-8'))

# %%
for _ in range(100):
    kafka_producer_obj.send('foobar', b'some_message_bytes')
